# %% [markdown]
# <td>
# <a href="https://colab.research.google.com/github/raoulg/MADS-MachineLearning-course/blob/master/notebooks/4_tuning_networks/01_hypertuner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# </td>

# %%
import sys
from pathlib import Path

try:
    notebook_dir = Path(__vsc_ipynb_file__).parent
except NameError:
    notebook_dir = Path("notebooks/4_tuning_networks").resolve()
sys.path.insert(0, str(notebook_dir))

import time
import numpy as np
from plotly import graph_objects as go
import matplotlib.pyplot as plt

from loguru import logger

import ray
from ray import tune

import torch
from torch import optim
from torch import nn

# %matplotlib inline
plt.style.use('dark_background')
# import plotly.io as pio
# pio.renderers.default = 'plotly_mimetype+notebook'

import visualize
DELETE = True # to delete the tunedir at the end of the notebook
start = time.time()

# %% [markdown]
# This is a general reference notebook to explore the use of ray tuner.
# First, we define some global variables. This makes it easier to change the parameters for the full notebook at once and run everything.
#
# Set the max_epochs to something like 10 (this will take longer, but you will get better results), and experiments to 18. This way, you will have a good way to compare gridsearch with the other tuners because gridsearch will do 3 * 6 = 18 experiments.
#
# The reason I am setting this low is because i automated the testing of the notebook and it takes a long time to run all the experiments by default.

# %%
MAX_EPOCHS = 3
N_EXPERIMENTS = 10

# %% [markdown]
# # Train function and config

# %% [markdown]
# Let's define some dicts to log the results of the training.

# %%
timer = {}
best_config = {}

# %% [markdown]
# We will need a training function. This is also implemented in the mltrainer, but I put it here to show you how the details work.

# %%
def train_fn(model, trainstreamer, lossfn, optimizer, steps, device):
    model.train() # set model to training model
    train_loss: float = 0.0 # start with 0 loss
    for _ in range(steps):
        x, y = next(trainstreamer) # get next batch
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad() # clear old gradients
        yhat = model(x) # make prediction
        loss = lossfn(yhat, y) # calculate loss
        loss.backward() # do backwards propagation
        optimizer.step() # tweak weights in the right direction
        train_loss += loss.item() # update the loss value
    return train_loss

# %% [markdown]
# We validate on the validation set and return the loss.

# %%
def validate(model, validstreamer, lossfn, metric, steps, device):
    model.eval() # set model to evaluation mode
    valid_loss: float = 0.0 # init loss with 0
    acc: float = 0.0 # initiate metric. why is it called acc?? accuracy? Strange since the metric is given as a parameter
    with torch.no_grad(): # disable gradients only make prediction and no updating of weights
        for _ in range(steps): 
            x, y = next(validstreamer) # get batch
            x = x.to(device)
            y = y.to(device)
            yhat = model(x) # make prediction
            loss = lossfn(yhat, y) # calculate loss
            valid_loss += loss.item() # update the loss
            acc += metric(y, yhat) # update the metric
    acc /= steps # calculate the average acc
    return valid_loss, acc # return loss and acc

# %% [markdown]
# Getting the data requires a bit extra care. Because we will run experiments in parallel on all the cpu's available, we well use FileLock to make sure that loading the data does not conflict.
#
# Note we import functions inside the function we will later on pass to ray. This is because ray will serialize the function and send it to the workers. If we import the functions outside the function, the workers will not have access to them.

# %%
def get_data(tune_dir):
    from filelock import FileLock
    from mads_datasets import DatasetFactoryProvider, DatasetType
    from mltrainer.preprocessors import PaddedPreprocessor
    from mads_datasets import DatasetFactoryProvider, DatasetType
    with FileLock(tune_dir / ".lock"):
        # we lock the datadir to avoid parallel instances trying to
        # access the datadir
        preprocessor = PaddedPreprocessor()
        gesturesdatasetfactory = DatasetFactoryProvider.create_factory(DatasetType.GESTURES)
        streamers = gesturesdatasetfactory.create_datastreamer(
            batchsize=32, preprocessor=preprocessor
        )
        train = streamers["train"]
        valid = streamers["valid"]
    return train, valid

# %% [markdown]
# We will use the same GRU model we used last lesson. You might improve this in a few ways (eg consider adding skip layers, conv1d, etc) but for clarity, lets keep it simple.

# %%
class GRUmodel(nn.Module):
    def __init__(
        self,
        config: dict,
    ) -> None:
        super().__init__()
        self.rnn = nn.GRU(
            input_size=config["input_size"],
            hidden_size=int(config["hidden_size"]),
            dropout=config["dropout"],
            batch_first=True,
            num_layers=int(config["num_layers"]),
        )
        self.linear = nn.Linear(int(config["hidden_size"]), config["output_size"])

    def forward(self, x):
        x, _ = self.rnn(x)
        last_step = x[:, -1, :]
        yhat = self.linear(last_step)
        return yhat

# %% [markdown]
# Now, we have all the ingredients we need to run the tuner.
# We create a function that:
# - loads the data with a lock
# - creates the model
# - trains the model
# - validates the model
# - reports the results to ray

# %%
def tune_model(config: dict):
    from mltrainer.metrics import Accuracy

    # load data
    train, valid = get_data(config["tune_dir"])
    trainsteps = len(train)
    validsteps = len(valid)
    trainstreamer = train.stream()
    validstreamer = valid.stream()

    # select device
    if torch.cuda.is_available():
        device = torch.device("cuda")
    elif torch.backends.mps.is_available() and torch.backends.mps.is_built():
        device = torch.device("mps")
    else:
        device = torch.device("cpu")
    print(device)

    # create model with config
    model = GRUmodel(config).to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    loss_fn = torch.nn.CrossEntropyLoss()
    metric = Accuracy()

    for _ in range(config["epochs"]):
        # train and validate
        train_loss = train_fn(model, trainstreamer, loss_fn, optimizer, trainsteps, device)
        valid_loss, accuracy = validate(model, validstreamer, loss_fn, metric, validsteps, device)
  
        # report to ray
        ray.train.report({
            "valid_loss": valid_loss / validsteps,
            "train_loss": train_loss / trainsteps,
            "accuracy" : accuracy,
            })

# %% [markdown]
# Let's try this, to see if everything works as expected.
# Note that it typically does not make sense to use accelaration here; we will typically have 1 GPU, but 10 or 16 CPUS. We gain much more from parallelizing the experiments than we gain by running the model faster on a single GPU.

# %%
tune_dir = Path("logs/test/").resolve()

# %%
config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.1,
    "hidden_size": 64,
    "num_layers": 2,
    "epochs": MAX_EPOCHS,
    "tune_dir": tune_dir,
}
tune_model(config)
# Out:
# 2026-03-12 04:52:45.613 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/stevenbontius/.cache/mads_datasets/gestures
# 100%|██████████| 2600/2600 [00:00<00:00, 4918.35it/s]
# 100%|██████████| 651/651 [00:00<00:00, 4994.86it/s]
# mps
# /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:657: UserWarning: `report` is meant to only be called inside a function that is executed by a Tuner or Trainer. Returning `None`.
#   warnings.warn(

# %% [markdown]
# # Key concepts
#
# In the ray documentation https://docs.ray.io/en/latest/tune/key-concepts.html#tune-search-spaces you can find an overview of all the types of search spaces. I will copy an example here
#
# ```python
# config = {
#     "uniform": tune.uniform(-5, -1),  # Uniform float between -5 and -1
#     "quniform": tune.quniform(3.2, 5.4, 0.2),  # Round to multiples of 0.2
#     "loguniform": tune.loguniform(1e-4, 1e-1),  # Uniform float in log space
#     "qloguniform": tune.qloguniform(1e-4, 1e-1, 5e-5),  # Round to multiples of 0.00005
#     "randn": tune.randn(10, 2),  # Normal distribution with mean 10 and sd 2
#     "qrandn": tune.qrandn(10, 2, 0.2),  # Round to multiples of 0.2
#     "randint": tune.randint(-9, 15),  # Random integer between -9 and 15
#     "qrandint": tune.qrandint(-21, 12, 3),  # Round to multiples of 3 (includes 12)
#     "lograndint": tune.lograndint(1, 10),  # Random integer in log space
#     "qlograndint": tune.qlograndint(1, 10, 2),  # Round to multiples of 2
#     "choice": tune.choice(["a", "b", "c"]),  # Choose one of these options uniformly
#     "func": tune.sample_from(
#         lambda spec: spec.config.uniform * 0.01
#     ),  # Depends on other value
#     "grid": tune.grid_search([32, 64, 128]),  # Search over all these values
# }
# ```
# but in the docs you can find more details about every option

# %% [markdown]
# # Random search

# %% [markdown]
# Now, let's do a random search.
#
# First, we define the search space. We can specify specific values, but also distributions.
# For the hidden size, we will use randint, which will sample from a uniform distribution of integers.
# The same for the number of layers.
#
# The `tune.run` function runs the hypertuning. It will sample from the search space, and create a specific config for each experiment.

# %%
config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.05,
    "epochs": MAX_EPOCHS,
    "hidden_size": tune.randint(16, 512),
    "num_layers": tune.randint(1, 8),
    "tune_dir": tune_dir,
}

# %% [markdown]
# Let's test this!

# %%
tic = time.time()
analysis = tune.run(
    tune_model,
    config=config,
    metric="valid_loss",
    mode="min",
    storage_path=str(tune_dir),
    num_samples=N_EXPERIMENTS,
    stop={"training_iteration": MAX_EPOCHS},
    verbose=1,
)

timer["ray_random"] = time.time() - tic
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2026-03-12 05:02:34</td></tr>
# <tr><td>Running for: </td><td>00:09:06.43        </td></tr>
# <tr><td>Memory:      </td><td>12.1/18.0 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/11 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc            </th><th style="text-align: right;">  hidden_size</th><th style="text-align: right;">  num_layers</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  valid_loss</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>tune_model_072d8_00000</td><td>TERMINATED</td><td>127.0.0.1:91797</td><td style="text-align: right;">          247</td><td style="text-align: right;">           6</td><td style="text-align: right;">    10</td><td style="text-align: right;">        455.393 </td><td style="text-align: right;">   0.119934 </td><td style="text-align: right;">   0.0995815</td><td style="text-align: right;">  0.973437</td></tr>
# <tr><td>tune_model_072d8_00001</td><td>TERMINATED</td><td>127.0.0.1:91795</td><td style="text-align: right;">          234</td><td style="text-align: right;">           2</td><td style="text-align: right;">    10</td><td style="text-align: right;">        163.132 </td><td style="text-align: right;">   0.0706369</td><td style="text-align: right;">   0.0206946</td><td style="text-align: right;">  0.985938</td></tr>
# <tr><td>tune_model_072d8_00002</td><td>TERMINATED</td><td>127.0.0.1:91799</td><td style="text-align: right;">          317</td><td style="text-align: right;">           3</td><td style="text-align: right;">    10</td><td style="text-align: right;">        250.734 </td><td style="text-align: right;">   0.0512459</td><td style="text-align: right;">   0.0408726</td><td style="text-align: right;">  0.98125 </td></tr>
# <tr><td>tune_model_072d8_00003</td><td>TERMINATED</td><td>127.0.0.1:91803</td><td style="text-align: right;">          470</td><td style="text-align: right;">           3</td><td style="text-align: right;">    10</td><td style="text-align: right;">        256.606 </td><td style="text-align: right;">   0.0369354</td><td style="text-align: right;">   0.0199286</td><td style="text-align: right;">  0.984375</td></tr>
/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 6385.90it/s]
# 100%|██████████| 651/651 [00:00<00:00, 7050.71it/s]
#  21%|██        | 548/2600 [00:00<00:00, 5477.26it/s]
#  50%|█████     | 1307/2600 [00:00<00:00, 6704.33it/s]
#  76%|███████▌  | 1978/2600 [00:00<00:00, 6245.10it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 6515.26it/s]
# 100%|██████████| 651/651 [00:00<00:00, 6585.66it/s]
#  24%|██▍       | 632/2600 [00:00<00:00, 6313.50it/s]
#  49%|████▊     | 1264/2600 [00:00<00:00, 5172.08it/s]
#  79%|███████▉  | 2055/2600 [00:00<00:00, 6286.31it/s]
# (tune_model pid=91799) 2026-03-12 04:53:37.969 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/stevenbontius/.cache/mads_datasets/gestures [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# 100%|██████████| 2600/2600 [00:00<00:00, 6095.05it/s]
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 14x across cluster]
# 100%|██████████| 651/651 [00:00<00:00, 4218.18it/s]
#  42%|████▏     | 1098/2600 [00:00<00:00, 5355.09it/s]
#  68%|██████▊   | 1759/2600 [00:00<00:00, 5918.05it/s]
#  90%|█████████ | 2352/2600 [00:00<00:00, 5816.33it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 5790.38it/s]
# (tune_model pid=91798) mps [repeated 8x across cluster]
# 100%|██████████| 651/651 [00:00<00:00, 6012.35it/s]
#  19%|█▉        | 492/2600 [00:00<00:00, 4914.90it/s]
#  38%|███▊      | 984/2600 [00:00<00:00, 3283.71it/s]
#  65%|██████▌   | 1693/2600 [00:00<00:00, 4617.38it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4662.94it/s]
#  69%|██████▉   | 448/651 [00:00<00:00, 4476.78it/s]
# 100%|██████████| 651/651 [00:00<00:00, 4578.93it/s]
#  14%|█▍        | 366/2600 [00:00<00:00, 2737.76it/s]
#  25%|██▍       | 640/2600 [00:00<00:01, 1790.33it/s]
#  42%|████▏     | 1082/2600 [00:00<00:00, 2642.20it/s]
#  57%|█████▋    | 1487/2600 [00:00<00:00, 3084.53it/s]
#  70%|███████   | 1832/2600 [00:00<00:00, 3127.79it/s]
#  84%|████████▍ | 2195/2600 [00:00<00:00, 3278.96it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 2807.42it/s]
#  25%|██▍       | 160/651 [00:00<00:00, 1537.32it/s]
#  79%|███████▉  | 516/651 [00:00<00:00, 1429.97it/s]
# 100%|██████████| 651/651 [00:00<00:00, 1321.00it/s]
# (tune_model pid=91802) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=91802)   _log_deprecation_warning(
# (tune_model pid=91803) 2026-03-12 04:53:40.250 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/stevenbontius/.cache/mads_datasets/gestures [repeated 3x across cluster]
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 6x across cluster]
# (tune_model pid=91795) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 2x across cluster]
# (tune_model pid=91795)   _log_deprecation_warning( [repeated 2x across cluster]
# (tune_model pid=91799) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=91799)   _log_deprecation_warning(
# (tune_model pid=91800) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=91800)   _log_deprecation_warning(
# (tune_model pid=91794) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 2x across cluster]
# (tune_model pid=91794)   _log_deprecation_warning( [repeated 2x across cluster]
# (tune_model pid=91796) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=91796)   _log_deprecation_warning(
# (tune_model pid=91797) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=91797)   _log_deprecation_warning(
# (tune_model pid=91798) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 2x across cluster]
# (tune_model pid=91798)   _log_deprecation_warning( [repeated 2x across cluster]
# (tune_model pid=91802) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=91802)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=91903) 2026-03-12 04:54:59.949 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/stevenbontius/.cache/mads_datasets/gestures
#   0%|          | 0/2600 [00:00<?, ?it/s]
#   2%|▏         | 56/2600 [00:00<00:04, 543.56it/s]
#  14%|█▍        | 361/2600 [00:00<00:01, 1998.70it/s]
#  22%|██▏       | 563/2600 [00:00<00:01, 1663.40it/s]
#  34%|███▎      | 876/2600 [00:00<00:00, 2174.87it/s]
#  61%|██████    | 1591/2600 [00:00<00:00, 2951.86it/s]
#  75%|███████▍  | 1944/2600 [00:00<00:00, 3117.57it/s]
#  87%|████████▋ | 2263/2600 [00:00<00:00, 2592.00it/s]
# 100%|██████████| 2600/2600 [00:01<00:00, 2563.43it/s]
#   0%|          | 0/651 [00:00<?, ?it/s]
#  61%|██████    | 395/651 [00:00<00:00, 3944.24it/s]
# 100%|██████████| 651/651 [00:00<00:00, 2612.68it/s]
# (tune_model pid=91903) mps [repeated 3x across cluster]
# (tune_model pid=91903) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=91903)   _log_deprecation_warning(
# (tune_model pid=91804) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=91804)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=92006) 2026-03-12 04:56:13.875 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/stevenbontius/.cache/mads_datasets/gestures
#   0%|          | 0/2600 [00:00<?, ?it/s]
#  13%|█▎        | 331/2600 [00:00<00:00, 3303.36it/s]
#  28%|██▊       | 724/2600 [00:00<00:00, 3668.08it/s]
#  42%|████▏     | 1091/2600 [00:00<00:00, 2202.65it/s]
#  52%|█████▏    | 1359/2600 [00:00<00:00, 1884.04it/s]
# (tune_model pid=91795) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=91795)   warnings.warn('resource_tracker: There appear to be %d '
#  66%|██████▌   | 1722/2600 [00:00<00:00, 2310.46it/s]
#  77%|███████▋  | 1993/2600 [00:00<00:00, 2276.73it/s]
#  86%|████████▋ | 2247/2600 [00:00<00:00, 2217.76it/s]
#  98%|█████████▊| 2550/2600 [00:01<00:00, 2426.97it/s]
# 100%|██████████| 2600/2600 [00:01<00:00, 2383.98it/s]
#  37%|███▋      | 243/651 [00:00<00:00, 2429.37it/s]
# 100%|██████████| 651/651 [00:00<00:00, 2464.22it/s]
# (tune_model pid=92006) mps
# (tune_model pid=92019) 2026-03-12 04:56:24.071 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/stevenbontius/.cache/mads_datasets/gestures
#   0%|          | 0/2600 [00:00<?, ?it/s]
#  13%|█▎        | 344/2600 [00:00<00:00, 3439.89it/s]
#  28%|██▊       | 729/2600 [00:00<00:00, 3666.65it/s]
#  57%|█████▋    | 1484/2600 [00:00<00:00, 3726.60it/s]
#  71%|███████▏  | 1857/2600 [00:00<00:00, 3111.83it/s]
#  84%|████████▍ | 2183/2600 [00:00<00:00, 2783.68it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 3190.20it/s]
#   0%|          | 0/651 [00:00<?, ?it/s]
#  41%|████      | 268/651 [00:00<00:00, 2474.08it/s]
#  79%|███████▉  | 516/651 [00:00<00:00, 2140.01it/s]
# 100%|██████████| 651/651 [00:00<00:00, 2401.73it/s]
# (tune_model pid=92019) mps
# (tune_model pid=92006) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=92006)   _log_deprecation_warning(
# (tune_model pid=92019) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=92019)   _log_deprecation_warning(
# (tune_model pid=91903) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=91903)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=91803) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutd
| INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/stevenbontius/.cache/mads_datasets/gestures [repeated 7x across cluster]
#  73%|███████▎  | 1895/2600 [00:00<00:00, 4450.52it/s]
#   0%|          | 0/2600 [00:00<?, ?it/s] [repeated 13x across cluster]
# 100%|██████████| 2600/2600 [00:00<00:00, 4447.94it/s]
# 100%|██████████| 651/651 [00:00<00:00, 5077.68it/s]
#  10%|█         | 271/2600 [00:00<00:00, 2708.08it/s]
#  24%|██▍       | 619/2600 [00:00<00:00, 3139.31it/s]
#  43%|████▎     | 1117/2600 [00:00<00:00, 3895.06it/s]
#  67%|██████▋   | 1731/2600 [00:00<00:00, 4767.14it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4392.77it/s]
#  68%|██████▊   | 440/651 [00:00<00:00, 4383.91it/s]
# 100%|██████████| 651/651 [00:00<00:00, 4061.62it/s]
# (tune_model pid=93075) mps [repeated 8x across cluster]
#  24%|██▍       | 636/2600 [00:00<00:00, 6357.46it/s]
#  49%|████▉     | 1272/2600 [00:00<00:00, 4020.45it/s]
#  66%|██████▌   | 1722/2600 [00:00<00:00, 4126.98it/s]
#  83%|████████▎ | 2164/2600 [00:00<00:00, 3996.90it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4204.60it/s]
#  21%|██        | 138/651 [00:00<00:00, 1376.13it/s]
# 100%|██████████| 651/651 [00:00<00:00, 2845.42it/s]
#  11%|█         | 284/2600 [00:00<00:00, 2838.38it/s]
#  22%|██▏       | 568/2600 [00:00<00:01, 1774.33it/s]
#  33%|███▎      | 869/2600 [00:00<00:00, 1888.74it/s]
#  41%|████      | 1071/2600 [00:00<00:00, 1836.52it/s]
#  49%|████▊     | 1262/2600 [00:00<00:00, 1832.60it/s]
#  59%|█████▊    | 1527/2600 [00:00<00:00, 2068.42it/s]
#  71%|███████   | 1848/2600 [00:00<00:00, 2083.45it/s]
#  79%|███████▉  | 2061/2600 [00:01<00:00, 1664.31it/s]
#  93%|█████████▎| 2421/2600 [00:01<00:00, 1987.75it/s]
# 100%|██████████| 2600/2600 [00:01<00:00, 1973.52it/s]
#  44%|████▎     | 284/651 [00:00<00:00, 2836.90it/s]
# 100%|██████████| 651/651 [00:00<00:00, 2575.44it/s]
# (tune_model pid=93072) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=93072)   _log_deprecation_warning(
# (tune_model pid=93080) 2026-03-12 05:05:02.029 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/stevenbontius/.cache/mads_datasets/gestures [repeated 3x across cluster]
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 7x across cluster]
# (tune_model pid=93073) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 2x across cluster]
# (tune_model pid=93073)   _log_deprecation_warning( [repeated 2x across cluster]
# (tune_model pid=93071) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 4x across cluster]
# (tune_model pid=93071)   _log_deprecation_warning( [repeated 4x across cluster]
# (tune_model pid=93072) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=93072)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=93077) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 3x across cluster]
# (tune_model pid=93077)   _log_deprecation_warning( [repeated 3x across cluster]
# (tune_model pid=93073) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown [repeated 2x across cluster]
# (tune_model pid=93073)   warnings.warn('resource_tracker: There appear to be %d ' [repeated 2x across cluster]
# (tune_model pid=93080) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=93080)   _log_deprecation_warning(
# (tune_model pid=93155) 2026-03-12 05:05:35.348 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/stevenbontius/.cache/mads_datasets/gestures
#
/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 3489.74it/s]
#  50%|████▉     | 325/651 [00:00<00:00, 1310.55it/s]
# 100%|██████████| 651/651 [00:00<00:00, 2011.74it/s]
# (tune_model pid=93188) mps [repeated 3x across cluster]
# (tune_model pid=93155) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=93155)   _log_deprecation_warning(
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 2x across cluster]
# (tune_model pid=93070) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=93070)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=93236) 2026-03-12 05:06:08.696 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/stevenbontius/.cache/mads_datasets/gestures
#   0%|          | 0/2600 [00:00<?, ?it/s]
#  15%|█▍        | 381/2600 [00:00<00:00, 3799.69it/s]
#  29%|██▉       | 761/2600 [00:00<00:00, 2951.09it/s]
#  41%|████      | 1068/2600 [00:00<00:00, 2982.04it/s]
#  53%|█████▎    | 1373/2600 [00:00<00:00, 2691.45it/s]
#  67%|██████▋   | 1731/2600 [00:00<00:00, 2969.27it/s]
#  78%|███████▊  | 2036/2600 [00:00<00:00, 2910.57it/s]
#  92%|█████████▏| 2386/2600 [00:00<00:00, 3083.66it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 2809.74it/s]
#   0%|          | 0/651 [00:00<?, ?it/s]
# 100%|██████████| 651/651 [00:00<00:00, 3802.44it/s]
# (tune_model pid=93236) mps
# (tune_model pid=93080) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=93080)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=93157) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=93157)   _log_deprecation_warning(
# (tune_model pid=93184) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 3x across cluster]
# (tune_model pid=93184)   _log_deprecation_warning( [repeated 3x across cluster]
# (tune_model pid=93155) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=93155)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=93188) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=93188)   _log_deprecation_warning(
# (tune_model pid=93236) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=93236)   _log_deprecation_warning(
# (tune_model pid=93157) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=93157)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=93184) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown [repeated 2x across cluster]
# (tune_model pid=93184)   warnings.warn('resource_tracker: There appear to be %d ' [repeated 2x across cluster]
# (tune_model pid=93236) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=93236)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=93586) 2026-03-12 05:08:22.950 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/stevenbontius/.cache/mads_datasets/gestures
#   0%|          | 0/2600 [00:00<?, ?it/s]
#  18%|█▊        | 469/2600 [00:00<00:00, 4680.83it/s]
#  36%|███▌      | 938/2600 [00:00<00:00, 3794.91it/s]
#  55%|█████▍    | 1429/2600 [00:00<00:00, 4245.34it/s]
#  73%|███████▎  | 1889/2600 [00:00<00:00, 4375.15it/s]
#  92%|█████████▏| 2382/2600 [00:00<00:00, 4565.70it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4183.41it/s]
#   0%|          | 0/651 [00:00<?, ?it/s]
# (tune_model pid=93586) mps
# 100%|██████████| 651/651 [00:00<00:00, 4386.35it/s]
#  34%|███▍      | 883/2600 [00:00<00:00, 8824.35it/s]
#  70%|██████▉   | 1807/2600 [00:00<00:00, 9063.45it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 8891.90it/s]
#  25%|██▌       | 652/2600 [00:00<00:00, 6513.10it/s]
#  54%|█████▍    | 1398/2600 [00:00<00:00, 7065.45it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 7460.48it/s]
# 100%|██████████| 651/651 [00:00<00:00, 6369.37it/s]
# (tune_model pid=93597) 2026-03-12 05:08:27.911 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/stevenbontius/.cache/mads_datasets/gestures [repeated 3x across cluster]
#   0%|          | 0/2600 [00:00<?, ?it/s] [repeated 5x across cluster]
#  24%|██▍       | 627/2600 [00:00<00:00, 6267.44it/s]
#  53%|█████▎    | 1374/2600 [00:00<00:00, 6969.58it/s]
#  80%|███████▉  | 2071/2600 [00:00<00:00, 6411.97it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 6236.21it/s]
# 100%|██████████| 651/651 [00:00<00:00, 7947.34it/s]
#  24%|██▍       | 637/2600 [00:00<00:00, 6345.93it/s]
#  53%|█████▎    | 1387/2600 [00:00<00:00, 6979.75it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 7058.29it/s]
#  40%|████      | 261/651 [00:00<00:00, 2609.45it/s]
# (tune_model pid=93604) mps [repeated 4x across cluster]
# 100%|██████████| 651/651 [00:00<00:00, 4190.94it/s]
#  27%|██▋       | 693/2600 [00:00<00:00, 6924.11it/s]
# ...
# (tune_model pid=93922)   _log_deprecation_warning( [repeated 2x across cluster]
# (tune_model pid=93927) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=93927)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=93925) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=93925)   _log_deprecation_warning(
# (tune_model pid=93926) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=93926)   _log_deprecation_warning(
# (tune_model pid=93923) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=93923)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=93921) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=93921)   _log_deprecation_warning(
# (tune_model pid=93924) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=93924)   _log_deprecation_warning(
# (tune_model pid=93928) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=93928)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=93919) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 3x across cluster]
# (tune_model pid=93919)   _log_deprecation_warning( [repeated 3x across cluster]
# (tune_model pid=93922) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=93922)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=93925) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=93925)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=93920) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=93920)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=93919) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=93919)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=94277) 2026-03-12 05:17:15.228 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/stevenbontius/.cache/mads_datasets/gestures
#   0%|          | 0/2600 [00:00<?, ?it/s]
#  16%|█▋        | 429/2600 [00:00<00:00, 4289.05it/s]
#  34%|███▍      | 885/2600 [00:00<00:00, 4447.50it/s]
#  53%|█████▎    | 1380/2600 [00:00<00:00, 4674.85it/s]
#  71%|███████   | 1848/2600 [00:00<00:00, 4638.87it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4650.48it/s]
#   0%|          | 0/651 [00:00<?, ?it/s]
#  42%|████▏     | 273/651 [00:00<00:00, 2724.64it/s]
# (tune_model pid=94277) mps
# 100%|██████████| 651/651 [00:00<00:00, 3628.44it/s]
#  32%|███▎      | 845/2600 [00:00<00:00, 8444.01it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 8964.31it/s]
# 100%|██████████| 651/651 [00:00<00:00, 7636.20it/s]
#  26%|██▌       | 677/2600 [00:00<00:00, 6767.02it/s]
#  58%|█████▊    | 1512/2600 [00:00<00:00, 7694.49it/s]
#  88%|████████▊ | 2300/2600 [00:00<00:00, 7775.59it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 7688.03it/s]
# 100%|██████████| 651/651 [00:00<00:00, 6335.59it/s]
# (tune_model pid=94290) 2026-03-12 05:17:20.831 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/stevenbontius/.cache/mads_datasets/gestures [repeated 3x across cluster]
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 4x across cluster]
#  12%|█▏        | 306/2600 [00:00<00:00, 3003.33it/s]
#  23%|██▎       | 607/2600 [00:00<00:00, 2723.13it/s]
#  39%|███▉      | 1025/2600 [00:00<00:00, 3345.83it/s]
#  54%|█████▍    | 1401/2600 [00:00<00:00, 3495.44it/s]
#  71%|███████▏  | 1858/2600 [00:00<00:00, 3847.83it/s]
# 100%|██████████| 2600/2600 [00:00<00:00,
/s]
# 100%|██████████| 2600/2600 [00:01<00:00, 2044.79it/s]
#  78%|███████▊  | 507/651 [00:00<00:00, 5058.46it/s]
# 100%|██████████| 651/651 [00:00<00:00, 4241.24it/s]
# (tune_model pid=94322) mps [repeated 2x across cluster]
# (tune_model pid=94327) 2026-03-12 05:17:42.158 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/stevenbontius/.cache/mads_datasets/gestures
#   7%|▋         | 188/2600 [00:00<00:03, 784.62it/s]
#   0%|          | 0/2600 [00:00<?, ?it/s] [repeated 3x across cluster]
#  17%|█▋        | 442/2600 [00:00<00:01, 1451.38it/s]
#  24%|██▎       | 615/2600 [00:00<00:02, 882.54it/s]
#  31%|███       | 809/2600 [00:00<00:01, 1117.74it/s]
#  37%|███▋      | 960/2600 [00:00<00:01, 1181.82it/s]
#  43%|████▎     | 1106/2600 [00:01<00:01, 1126.74it/s]
#  48%|████▊     | 1238/2600 [00:01<00:01, 1069.74it/s]
#  58%|█████▊    | 1499/2600 [00:01<00:00, 1441.21it/s]
#  68%|██████▊   | 1778/2600 [00:01<00:00, 1750.94it/s]
#  76%|███████▌  | 1971/2600 [00:01<00:00, 1414.76it/s]
#  85%|████████▌ | 2215/2600 [00:01<00:00, 1495.14it/s]
#  94%|█████████▎| 2435/2600 [00:01<00:00, 1655.70it/s]
# 100%|██████████| 2600/2600 [00:01<00:00, 1307.00it/s]
# (tune_model pid=94277) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=94277)   _log_deprecation_warning(
#  54%|█████▍    | 351/651 [00:00<00:00, 2144.34it/s]
# (tune_model pid=94327) mps
# 100%|██████████| 651/651 [00:00<00:00, 1950.27it/s]
#   0%|          | 0/651 [00:00<?, ?it/s]
# (tune_model pid=94283) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=94283)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=94286) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 2x across cluster]
# (tune_model pid=94286)   _log_deprecation_warning( [repeated 2x across cluster]
# (tune_model pid=94319) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=94319)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=94298) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 2x across cluster]
# (tune_model pid=94298)   _log_deprecation_warning( [repeated 2x across cluster]
# (tune_model pid=94290) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 2x across cluster]
# (tune_model pid=94290)   _log_deprecation_warning( [repeated 2x across cluster]
# (tune_model pid=94307) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=94307)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=94322) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 3x across cluster]
# (tune_model pid=94322)   _log_deprecation_warning( [repeated 3x across cluster]
# (tune_model pid=94322) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=94322)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=94315) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=94315)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=94286) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=94286)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=94290) /Users/stevenbontius/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=94290)   warnings.warn('resource_tracker: There appear to be %d '

# %%
def plot_contour(df, x, y, z, start=0.90, end=1.0, size=0.01):
    fig = go.Figure()

    fig.add_trace(
        go.Contour(
            z=df[z],
            x=df[x],
            y=df[y],
            contours=dict(
                coloring='heatmap',
                showlabels=True,  # show labels on contours
                start=start,       # start of the contour range
                end=end,          # end of the contour range
                size=size,
            ),
            colorscale="plasma",
            colorbar=dict(
                title='Accuracy'
            )
        )
    )

    fig.add_trace(
        go.Scatter(
            x=df[x],
            y=df[y],
            mode='markers',
            marker=dict(
                color='black',
                size=8,
                symbol='circle'
            ),
            customdata=df['accuracy'],  # Pass accuracy values for hover text
            hovertemplate=(
                'Hidden Size: %{x}<br>'
                'Number of Layers: %{y}<br>'
                'Accuracy: %{customdata:.4f}<extra></extra>'
            ),
            name='Data Points'
        )
    )

    fig.update_layout(
        title="Contour Plot",
        xaxis_title="Hidden Size",
        yaxis_title="Number of Layers",
        xaxis=dict(showgrid=False),  # Remove x-axis grid lines
        yaxis=dict(showgrid=False),
        plot_bgcolor='white',        # Set background color to white
        paper_bgcolor='white'
    )

    fig.show()

# %%
all_results = analysis.results_df

# %%
random = analysis.results_df
plot_contour(random, "config/hidden_size", "config/num_layers", "accuracy")

# %% [markdown]
# As you can see, the search space is sort of randomly sampled.
# Even though big parts are unexplored, it still looks like we find some hotspots.

# %%
best = analysis.get_best_config()
best["accuracy"] = analysis.best_result["accuracy"]
best_config["random"] = best

# %% [markdown]
# So, we searched the hyperparameter space. Problem is, these spaces potentially can get
# pretty big. Let's imagine you have 10 hyperparameters, and every hyperparameter has 5
# possible (relevant) values, you already have $5^{10}$ possible combinations, which is almost 10 million. Even if checking of every configuration would take just 1 second, it would take more than a 100 days to check them all...This
# space can grow out of control pretty fast.
#
# Lets look at the best results we found.

# %%
best
# Out:
# {'input_size': 3,
#  'output_size': 20,
#  'dropout': 0.05,
#  'epochs': 10,
#  'hidden_size': 258,
#  'num_layers': 3,
#  'tune_dir': PosixPath('/Users/stevenbontius/Documents/Projects/MADS/MADS-ML-StevenB/logs/test'),
#  'accuracy': 0.9953125}

# %%
columns = ["config/hidden_size", "config/num_layers", "accuracy"]
visualize.parallel_plot(analysis, columns)

# %% [markdown]
# Note how the mean scores are sort of randomly distributed. This is a direct
# effect of random guessing parameters.

# %% [markdown]
# # Grid search

# %% [markdown]
# We can do this more rigorous with a gridsearch.
# The upside of this technique is that you will test every configuration.
#
# A huge downside is the inefficiency. Also, you will run experiments with combinations that might be not very promising, but very slow, which is pretty inefficient.
#
#
# One way to handle this is to use doubling as a strategy to scan the range: 16, 32, ..., 512. This is a bit more efficient.
#
# Typically, this can be a good idea for a first scan, to get a rough idea of the space.
# After you have done this, you can narrow your searchspace, and do a more fine grained search zoomed in on areas that seem promising.

# %%
config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.1,
    "epochs": MAX_EPOCHS,
    "hidden_size": tune.grid_search([16, 32, 64, 128, 256, 512]),
    "num_layers": tune.grid_search([2, 4, 8]),
    "tune_dir": tune_dir,
}

# %%
tic = time.time()

analysis = tune.run(
    tune_model,
    config=config,
    metric="valid_loss",
    mode="min",
    storage_path=str(tune_dir),
    stop={"training_iteration": MAX_EPOCHS},
    verbose=1,
)

timer["ray_grid"] = time.time() - tic

best = analysis.get_best_config()
best["accuracy"] = analysis.best_result["accuracy"]
best_config["grid"] = best
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2026-03-12 05:07:32</td></tr>
# <tr><td>Running for: </td><td>00:02:42.98        </td></tr>
# <tr><td>Memory:      </td><td>11.9/18.0 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/11 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc            </th><th style="text-align: right;">  hidden_size</th><th style="text-align: right;">  num_layers</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  valid_loss</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>tune_model
# <tr><td>tune_model_9d70e_00009</td><td>TERMINATED</td><td>127.0.0.1:93071</td><td style="text-align: right;">          128</td><td style="text-align: right;">           4</td><td style="text-align: right;">     3</td><td style="text-align: right;">         70.1012</td><td style="text-align: right;">    1.41564 </td><td style="text-align: right;">    1.43326 </td><td style="text-align: right;">  0.4     </td></tr>
# <tr><td>tune_model_9d70e_00010</td><td>TERMINATED</td><td>127.0.0.1:93080</td><td style="text-align: right;">          256</td><td style="text-align: right;">           4</td><td style="text-align: right;">     3</td><td style="text-align: right;">         79.4883</td><td style="text-align: right;">    0.637376</td><td style="text-align: right;">    0.980595</td><td style="text-align: right;">  0.784375</td></tr>
# <tr><td>tune_model_9d70e_00011</td><td>TERMINATED</td><td>127.0.0.1:93155</td><td style="text-align: right;">          512</td><td style="text-align: right;">           4</td><td style="text-align: right;">     3</td><td style="text-align: right;">         63.2841</td><td style="text-align: right;">    0.214475</td><td style="text-align: right;">    0.403591</td><td style="text-align: right;">  0.934375</td></tr>
# <tr><td>tune_model_9d70e_00012</td><td>TERMINATED</td><td>127.0.0.1:93157</td><td style="text-align: right;">           16</td><td style="text-align: right;">           8</td><td style="text-align: right;">     3</td><td style="text-align: right;">         97.6998</td><td style="text-align: right;">    2.32062 </td><td style="text-align: right;">    2.39755 </td><td style="text-align: right;">  0.198437</td></tr>
# <tr><td>tune_model_9d70e_00013</td><td>TERMINATED</td><td>127.0.0.1:93166</td><td style="text-align: right;">           32</td><td style="text-align: right;">           8</td><td style="text-align: right;">     3</td><td style="text-align: right;">         95.1612</td><td style="text-align: right;">    2.02916 </td><td style="text-align: right;">    2.12539 </td><td style="text-align: right;">  0.214062</td></tr>
# <tr><td>tune_model_9d70e_00014</td><td>TERMINATED</td><td>127.0.0.1:93173</td><td style="text-align: right;">           64</td><td style="text-align: right;">           8</td><td style="text-align: right;">     3</td><td style="text-align: right;">         96.2047</td><td style="text-align: right;">    2.09792 </td><td style="text-align: right;">    1.71911 </td><td style="text-align: right;">  0.25    </td></tr>
# <tr><td>tune_model_9d70e_00015</td><td>TERMINATED</td><td>127.0.0.1:93184</td><td style="text-align: right;">          128</td><td style="text-align: right;">           8</td><td style="text-align: right;">     3</td><td style="text-align: right;">         96.4409</td><td style="text-align: right;">    1.56909 </td><td style="text-align: right;">    1.72585 </td><td style="text-align: right;">  0.298438</td></tr>
# <tr><td>tune_model_9d70e_00016</td><td>TERMINATED</td><td>127.0.0.1:93188</td><td style="text-align: right;">          256</td><td style="text-align: right;">           8</td><td style="text-align:
# 2026-03-12 05:07:32,708	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/stevenbontius/Documents/Projects/MADS/MADS-ML-StevenB/logs/test/tune_model_2026-03-12_05-04-49' in 0.0065s.
# 2026-03-12 05:07:32,713	INFO tune.py:1041 -- Total run time: 163.00 seconds (162.97 seconds for the tuning loop).

# %%
import pandas as pd
all_results = pd.concat([all_results, analysis.results_df])

# %%
grid = analysis.results_df
plot_contour(grid, "config/hidden_size", "config/num_layers", "accuracy", start=0.7)

# %% [markdown]
# As you can see, we get a systematic scan, but large parts of the space are still unexplored, and we also explored parts that are really not very promising.

# %%
visualize.parallel_plot(analysis, columns)

# %%
visualize.plot_timers(timer)

# %% [markdown]
# # Bayes

# %% [markdown]
# Now, we improve the search algorithm with a bayesian optimization.
#
# Note that the bayesian search algorithm will only work with continuous parameters. This is a problem for the number of layers, which is a discrete parameter. I fixed this by simply casting the parameters to an integer inside the model, which is not very elegant but it works.

# %%
from ray.tune.search.bayesopt import BayesOptSearch

bayesopt = BayesOptSearch(metric="valid_loss", mode="min")


config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.1,
    "epochs": MAX_EPOCHS,
    "hidden_size": tune.uniform(16, 512),
    "num_layers": tune.uniform(1, 8),
    "tune_dir": tune_dir,
}

tic = time.time()

analysis = tune.run(
    tune_model,
    config=config,
    metric="valid_loss",
    mode="min",
    storage_path=str(tune_dir),
    num_samples=N_EXPERIMENTS,
    stop={"training_iteration": MAX_EPOCHS},
    search_alg=bayesopt,
    verbose=1,
)

timer["ray_bayes"] = time.time() - tic

best = analysis.get_best_config()
best["accuracy"] = analysis.best_result["accuracy"]
best_config["bayes"] = best
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2026-03-12 05:10:06</td></tr>
# <tr><td>Running for: </td><td>00:01:45.73        </td></tr>
# <tr><td>Memory:      </td><td>12.3/18.0 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/11 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name         </th><th>status    </th><th>loc            </th><th style="text-align: right;">  hidden_size</th><th style="text-align: right;">  num_layers</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  valid_loss</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>tune_model_5718cf5f</td><td>TERMINATED</td><td>127.0.0.1:93586</td><td style="text-align: right;">     201.772 </td><td style="text-align: right;">     7.655  </td><td style="text-align: right;">     3</td><td style="text-align: right;">        100.408 </td><td style="text-align: right;">    1.27844 </td><td style="text-align: right;">    1.4325  </td><td style="text-align: right;">  0.423438</td></tr>
# <tr><td>tune_model_d8d90890</td><td>TERMINATED</td><td>127.0.0.1:93591</td><td style="text-align: right;">     379.069 </td><td style="text-align: right;">     5.19061</td><td style="text-align: right;">     3</td><td style="text-align: right;">         83.7461</td><td style="text-align: right;">    0.592486</td><td style="text-align: right;">    0.937721</td><td style="text-align: right;">  0.792188</td></tr>
# <tr><td>tune_model_24ee4372</td><td>TERMINATED</td><td>127.0.0.1:93594</td><td style="text-align: right;">      93.3852</td><td style="text-align: right;">     2.09196</td><td style="text-align: right;">     3</td><td style="text-align: right;">         35.9992</td><td style="text-align: right;">    1.35023 </td><td style="text-align: right;">    1.61954 </td><td style="text-align: right;">  0.482812</td></tr>
# <tr><td>tune_model_b5f44907</td><td>TERMINATED</td><td>127.0.0.1:93597</td><td style="text-align: right;">      44.8095</td><td style="text-align: right;">     7.06323</td><td style="text-align: right;">     3</td><td style="text-align: right;">         96.6656</td><td style="text-align: right;">    1.99752 </td><td style="text-align: right;">    2.14011 </td><td style="text-align: right;">  0.245312</td></tr>
# <tr><td>tune_model_05a2b1cf</td><td>TERMINATED</td><td>127.0.0.1:93604</td><td style="text-align: right;">     314.153 </td><td style="text-align: right;">     5.95651</td><td style="text-align: right;">     3</td><td style="text-align: right;">         83.8244</td><td style="text-align: right;">    0.562748</td><td style="text-align: right;">    0.721343</td><td style="text-align: right;">  0.782813</td></tr>
# <tr><td>tune_model_73149b8c</td><td>TERMINATED</td><td>127.0.0.1:93612</td><td style="text-align: right;">      26.2099</td><td style="text-align: right;">     7.78937</td><td style="text-align: right;">     3</td><td style="text-align: right;">         95.1006</td><td style="text-align: right;">    2.28009 </td><td style="text-align: right;">    2.2824  </td><td style="text-align: right;">  0.192188</td></tr>
# <tr><td>tune_model_00a4b945</td><td>TERMINATED</td><td>127.0.0.1:93614</td><td style="text-align: right;">     428.892 </td><td style="text-align: right;">     2.48637</td><td style="text-align: right;">     3</td><td style="text-align: right;">         43.5973</td><td style="text-align: right;">    0.238213</td><td style="text-align: right;">    0.489867</td><td style="text-align: right;">  0.95    </td></tr>
# <tr><td>tune_model_1b51c282</td><td>TERMINATED</td><td>127.0.0.1:93625</td><td style="text-align: right;">     106.185 </td><td style="text-align: right;">     2.28383</td><td style="text-align: right;">     3</td><td style="text-align: right;">         43.8824</td><td style="text-align: right;">    1.4371  </td><td style="text-align: right;">    1.69306 </td><td style="text-align: right;">  0.489063</td></tr>
# <tr><td>tune_model_950a24fb</td><td>TERMINATED</td><td>127.0.0.1:93627</td><td style="text-align: right;">     166.904 </td><td style="text-align: right;">     4.6733 </td><td style="text-align: right;">     3</td><td style="text-align: right;">         72.473 </td><td style="text-align: right;">    0.879563</td><td style="text-align: right;">    1.10376 </td><td style="text-align: right;">  0.667188</td></tr>
# <tr><td>tune_model_6d005e0b</td><td>TERMINATED</td><td>127.0.0.1:93634</td><td style="text-align: right;">     230.245 </td><td style="text-align: right;">     3.0386 </td><td style="text-align: right;">     3</td><td style="text-align: right;">         57.5978</td><td style="text-align: right;">    0.476222</td><td style="text-align: right;">    0.785479</td><td style="text-align: right;">  0.85    </td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2026-03-12 05:10:06,343	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/stevenbontius/Documents/Projects/MADS/MADS-ML-StevenB/logs/test/tune_model_2026-03-12_05-08-20' in 0.0061s.
# 2026-03-12 05:10:06,346	INFO tune.py:1041 -- Total run time: 105.74 seconds (105.72 seconds for the tuning loop).

# %%
best
# Out:
# {'input_size': 3,
#  'output_size': 20,
#  'dropout': 0.1,
#  'epochs': 3,
#  'hidden_size': np.float64(428.89154983700917),
#  'num_layers': np.float64(2.486373774747933),
#  'tune_dir': PosixPath('/Users/stevenbontius/Documents/Projects/MADS/MADS-ML-StevenB/logs/test'),
#  'accuracy': 0.95}

# %%
all_results = pd.concat([all_results, analysis.results_df])

# %%
bayes = analysis.results_df
plot_contour(bayes, "config/hidden_size", "config/num_layers", "accuracy", start=0.7)

# %% [markdown]
# As you can see, bayes really focuses on the promising areas. It is much more efficient than random search, and also more efficient than grid search.
# We have set the `random_search_steps` to 5, this means that we will do 5 random searches first, to get a good initial idea of the space. As you can see, 5 is a bit low, because it might lead to premature converging to a local optimum. You can increase this number to get a better initial idea of the space, but you will also need to increase the number of iterations after the initial random scan.

# %%
visualize.parallel_plot(analysis, columns)

# %%
visualize.plot_timers(timer)

# %%
import pandas as pd

pd.DataFrame.from_dict(best_config, orient="index")
# Out:
#         input_size  output_size  dropout  epochs  hidden_size  num_layers  \
# random           3           20     0.05      10    258.00000    3.000000
# grid             3           20     0.10       3    512.00000    2.000000
# bayes            3           20     0.10       3    428.89155    2.486374
#
#                                                  tune_dir  accuracy
# random  /Users/stevenbontius/Documents/Projects/MADS/M...  0.995313
# grid    /Users/stevenbontius/Documents/Projects/MADS/M...  0.937500
# bayes   /Users/stevenbontius/Documents/Projects/MADS/M...  0.950000

# %% [markdown]
# # Hyperband
#
# Hyperband aborts runs early. Configs that are unpromising are abandoned before they complete.

# %%
from ray.tune.schedulers import AsyncHyperBandScheduler

scheduler = AsyncHyperBandScheduler(
    time_attr="training_iteration", grace_period=1, reduction_factor=3, max_t=MAX_EPOCHS
)

config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.1,
    "epochs": MAX_EPOCHS,
    "hidden_size": tune.randint(16, 512),
    "num_layers": tune.randint(1, 8),
    "tune_dir": tune_dir,
}

tic = time.time()
analysis = tune.run(
    tune_model,
    config=config,
    metric="valid_loss",
    mode="min",
    storage_path=str(tune_dir),
    num_samples=N_EXPERIMENTS,
    stop={"training_iteration": MAX_EPOCHS},
    scheduler=scheduler,
    verbose=1,
)

timer["ray_hyperband"] = time.time() - tic

best = analysis.get_best_config()
best["accuracy"] = analysis.best_result["accuracy"]
best_config["hyperband"] = best
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2026-03-12 05:13:20</td></tr>
# <tr><td>Running for: </td><td>00:01:43.38        </td></tr>
# <tr><td>Memory:      </td><td>12.6/18.0 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped
# <tr><td>tune_model_9071c_00009</td><td>TERMINATED</td><td>127.0.0.1:93927</td><td style="text-align: right;">          400</td><td style="text-align: right;">           1</td><td style="text-align: right;">     3</td><td style="text-align: right;">         28.839 </td><td style="text-align: right;">    0.650386</td><td style="text-align: right;">    0.9765  </td><td style="text-align: right;">  0.775   </td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2026-03-12 05:13:20,802	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/stevenbontius/Documents/Projects/MADS/MADS-ML-StevenB/logs/test/tune_model_2026-03-12_05-11-37' in 0.0062s.
# 2026-03-12 05:13:20,807	INFO tune.py:1041 -- Total run time: 103.41 seconds (103.37 seconds for the tuning loop).

# %% [markdown]
# If you study the iter column, you will see that some runs have been stopped early. This is exactly the point of hyperband: it tries to allocate resources to the most promising configurations.
#
# The downside of this, is that if you try to get a good view of the space, you get distorted results because comparing a model that has trained just 1 or 3 epochs with a model that has trained 100 epochs is not very fair...

# %%
all_results = pd.concat([all_results, analysis.results_df])

# %%
hyperband = analysis.results_df
plot_contour(hyperband, "config/hidden_size", "config/num_layers", "accuracy", start=0.7)

# %%
visualize.parallel_plot(analysis, columns)

# %% [markdown]
# But note that it is faster! This means you could do more runs in the same time, which might be a good tradeoff!
# Typically you will get better results if you scan the searchspace better by doing more runs, aborting the ones that are not promising and going on with the ones that seem to yield good results.

# %%
visualize.plot_timers(timer)

# %%
pd.DataFrame.from_dict(best_config, orient="index")
# Out:
#            input_size  output_size  dropout  epochs  hidden_size  num_layers  \
# random              3           20     0.05      10    258.00000    3.000000
# grid                3           20     0.10       3    512.00000    2.000000
# bayes               3           20     0.10       3    428.89155    2.486374
# hyperband           3           20     0.10       3    510.00000    3.000000
#
#                                                     tune_dir  accuracy
# random     /Users/stevenbontius/Documents/Projects/MADS/M...  0.995313
# grid       /Users/stevenbontius/Documents/Projects/MADS/M...  0.937500
# bayes      /Users/stevenbontius/Documents/Projects/MADS/M...  0.950000
# hyperband  /Users/stevenbontius/Documents/Projects/MADS/M...  0.965625

# %% [markdown]
# # Hyperbayes

# %% [markdown]
# It is possible to combine Hyperband with Bayesian optimization, implemented as `TuneBOHB` in ray.
# However, `TuneBOHB` in ray is dependent on `hpbandster`, which is not maintained anymore.
# Unfortunately, a dependency of `hpbandster` is `netifaces`, which is also not maintained anymore.
# While `netifaces` does work on some hardware, it fails to build on some other hardware, which is a problem.
#
# To still use BOHB type algoritms, I am planning to implement either SMAC3 or BEHB in the future.

# %% [markdown]
# # HyperOpt
# HyperOpt provides gradient/derivative-free optimization. They implemented TPE, which stands for Tree-structured Parzen Estimator. This is a bayesian optimization algorithm that uses a tree to model the distribution of the objective function. The main advantage is that TPE also works with discrete parameters and conditional search spaces which is a problem for the bayesian optimization.
#
# For example, you could do things like this:
# ```python
# conditional_space = {
#     "activation": hp.choice(
#         "activation",
#         [
#             {"activation": "relu", "mult": hp.uniform("mult", 1, 2)},
#             {"activation": "tanh"},
#         ],
#     ),
# }
# ```
#
# Where you have a discrete parameter `activation` that has a conditional parameter `mult`. This means that if you choose `relu`, you also need to set `mult`, but if you choose `tanh`, you do not need to set `mult`. See [documentation of ray](https://docs.ray.io/en/latest/tune/examples/hyperopt_example.html) for more details.

# %%
from ray.tune.search.hyperopt import HyperOptSearch
search = HyperOptSearch()

scheduler = AsyncHyperBandScheduler(
    time_attr="training_iteration", grace_period=1, reduction_factor=3, max_t=MAX_EPOCHS
)

# %%
config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.1,
    "epochs": MAX_EPOCHS,
    "hidden_size": tune.randint(16, 512),
    "num_layers": tune.randint(1, 8),
    "tune_dir": tune_dir,
}

tic = time.time()
analysis = tune.run(
    tune_model,
    config=config,
    metric="valid_loss",
    mode="min",
    storage_path=str(tune_dir),
    num_samples=N_EXPERIMENTS,
    stop={"training_iteration": MAX_EPOCHS},
    search_alg=search,
    scheduler=scheduler,
    verbose=1,
)

timer["ray_hyperopt"] = time.time() - tic

best = analysis.get_best_config()
best["accuracy"] = analysis.best_result["accuracy"]
best_config["hyperopt"] = best
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2026-03-12 05:19:01</td></tr>
# <tr><td>Running for: </td><td>00:01:48.74        </td></tr>
# <tr><td>Memory:      </td><td>12.3/18.0 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=5<br>Bracket: Iter 3.000: -0.44847364326318095 | Iter 1.000: -1.869132435321808<br>Logical resource usage: 1.0/11 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name         </th><th>status    </th><th>loc            </th><th style="text-align: right;">  dropout</th><th style="text-align: right;">  epochs</th><th style="text-align: right;">  hidden_size</th><th style="text-align: right;">  input_size</th><th style="text-align: right;">  num_layers</th><th style="text-align: right;">  output_size</th><th>tune_dir            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  valid_loss</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>tune_model_8fd02d88</td><td>TERMINATED</td><td>127.0.0.1:94277</td><td style="text-align: right;">      0.1</td><td style="text-align: right;">       3</td><td style="text-align: right;">          185</td><td style="text-align: right;">           3</td><td style="text-align: right;">           5</td><td style="text-align: right;">           20</td><td>/Users/stevenbo_6380</td><td style="text-align: right;">     3</td><td style="text-align: right;">         84.6998</td><td style="text-align: right;">    1.04754 </td><td style="text-align: right;">    1.22552 </td><td style="text-align: right;">  0.617188</td></tr>
# <tr><td>tune_model_d5b993f9</td><td>TERMINATED</td><td>127.0.0.1:94283</td><td style="text-align: right;">      0.1</td><td style="text-align: right;">       3</td><td style="text-align: right;">          120</td><td style="text-align: right;">           3</td><td style="text-align: right;">           5</td><td style="text-align: right;">           20</td><td>/Users/stevenbo_6380</td><td style="text-align: right;">     1</td><td style="text-align: right;">         32.7545</td><td style="text-align: right;">    2.15743 </td><td style="text-align: right;">    2.46935 </td><td style="text-align: right;">  0.240625</td></tr>
# <tr><td>tune_model_00b1f5c6</td><td>TERMINATED</td><td>127.0.0.1:94286</td><td style="text-align: right;">      0.1</td><td style="text-align: right;">
td><td style="text-align: right;">      0.1</td><td style="text-align: right;">       3</td><td style="text-align: right;">          284</td><td style="text-align: right;">           3</td><td style="text-align: right;">           5</td><td style="text-align: right;">           20</td><td>/Users/stevenbo_6380</td><td style="text-align: right;">     1</td><td style="text-align: right;">         43.2521</td><td style="text-align: right;">    1.87459 </td><td style="text-align: right;">    2.39902 </td><td style="text-align: right;">  0.290625</td></tr>
# <tr><td>tune_model_408e35ba</td><td>TERMINATED</td><td>127.0.0.1:94327</td><td style="text-align: right;">      0.1</td><td style="text-align: right;">       3</td><td style="text-align: right;">          295</td><td style="text-align: right;">           3</td><td style="text-align: right;">           4</td><td style="text-align: right;">           20</td><td>/Users/stevenbo_6380</td><td style="text-align: right;">     1</td><td style="text-align: right;">         35.9317</td><td style="text-align: right;">    1.91734 </td><td style="text-align: right;">    2.32988 </td><td style="text-align: right;">  0.267188</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStat
# 2026-03-12 05:17:48,566	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2026-03-12 05:17:55,535	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2026-03-12 05:18:11,872	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2026-03-12 05:18:16,059	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2026-03-12 05:18:18,329	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2026-03-12 05:18:39,207	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2026-03-12 05:18:41,738	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2026-03-12 05:18:43,250	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2026-03-12 05:18:47,154	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2026-03-12 05:19:01,447	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2026-03-12 05:19:01,455	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/stevenbontius/Documents/Projects/MADS/MADS-ML-StevenB/logs/test/tune_model_2026-03-12_05-17-12' in 0.0060s.
# 2026-03-12 05:19:01,458	INFO tune.py:1041 -- Total run time: 108.77 seconds (108.73 seconds for the tuning loop).

# %%
all_results = pd.concat([all_results, analysis.results_df])

# %%
hyperbayes = analysis.results_df
plot_contour(hyperbayes, "config/hidden_size", "config/num_layers", "accuracy", start=0.3, size=0.05)

# %% [markdown]
# This model combines bayesian optimization with hyperband. This is a good idea, because it combines the efficiency of bayesian optimization with the speed of hyperband.

# %%
visualize.parallel_plot(analysis, columns)

# %%
visualize.plot_timers(timer)

# %%
pd.DataFrame.from_dict(best_config, orient="index")
# Out:
#            input_size  output_size  dropout  epochs  hidden_size  num_layers  \
# random              3           20     0.05      10    258.00000    3.000000
# grid                3           20     0.10       3    512.00000    2.000000
# bayes               3           20     0.10       3    428.89155    2.486374
# hyperband           3           20     0.10       3    510.00000    3.000000
# hyperopt            3           20     0.10       3    384.00000    4.000000
#
#                                                     tune_dir  accuracy
# random     /Users/stevenbontius/Documents/Projects/MADS/M...  0.995313
# grid       /Users/stevenbontius/Documents/Projects/MADS/M...  0.937500
# bayes      /Users/stevenbontius/Documents/Projects/MADS/M...  0.950000
# hyperband  /Users/stevenbontius/Documents/Projects/MADS/M...  0.965625
# hyperopt   /Users/stevenbontius/Documents/Projects/MADS/M...  0.932813

# %%
contour = all_results[all_results["training_iteration"] == MAX_EPOCHS]
plot_contour(contour, "config/hidden_size", "config/num_layers", "accuracy", start=0.8)

# %%
stop = time.time() - start
print(stop)
# Out:
# 1023.3283128738403

# %%
if DELETE:
    import shutil
    shutil.rmtree(tune_dir)
